# %% [markdown]
# # **📊 Projeto Final: Análise de Dados Educacionais**
#
# ## **Bem-vindo ao Projeto Final do Curso de Python da FEA.dev!** 🎉
#
# Chegou a hora de colocar em prática tudo o que você aprendeu no curso! Neste desafio, você vai explorar e analisar um conjunto de dados sobre o desempenho acadêmico de estudantes. Seu objetivo será realizar uma análise exploratória completa e responder a uma pergunta norteadora, gerando insights a partir dos dados.
#
# ---
#
# ## **🚀 O Desafio**
#
# ### **Pergunta Norteadora**:
# **"Quais fatores demográficos, acadêmicos e comportamentais mais influenciam a classificação e a média de notas dos estudantes?"**
#
# As variáveis de interesse são **`Classificacao_Notas` e `Media_Notas`**. Investigue como elas se relaciona com outros fatores, como idade, gênero, faltas, horas de estudo e participação em atividades extracurriculares. 📝
#
# ---
#
# ## **📌 Etapas do Desafio**
#
# 1. **Importação e Exploração dos Dados**:
#    - Leia o dataset e obtenha uma visão geral das informações.
#    - Verifique o formato dos dados, tipos de variáveis e valores ausentes ou duplicados.
#
# 2. **Preparação e Limpeza**:
#    - Renomeie colunas, trate valores ausentes e ajuste os dados conforme necessário.
#    - Crie novas colunas, se útil para a análise ou visualização.
#
# 3. **Análise Exploratória**:
#    - Investigue a relação entre **`Classificacao_Notas` e `Media_Notas`** com outras variáveis.
#    - Exemplos de perguntas a explorar:
#      - Alunos que participam de atividades extracurriculares têm melhor desempenho?
#      - O número de faltas impacta a classificação?
#      - Há diferenças de desempenho por idade, gênero ou etnia?
#
# 4. **Visualização de Dados**:
#    - Crie gráficos (ex.: histogramas, boxplots, scatter plots) para apresentar os padrões encontrados de forma clara e visualmente atraente. 📈
#
# 5. **Conclusões**:
#    - Resuma os principais insights.
#    - Destaque os fatores mais relevantes que influenciam as classificações e as médias de notas.
#
# ---
#
# ## **📋 Regras e Diretrizes**
# - Este desafio é focado em análise exploratória e visualização de dados.
# - Documente seu processo com comentários no código.
# - Seja criativo nas análises e visualizações! 🖌️
#
# ---
#
# ## **Dica Extra:**
#
# Use documentações, tutoriais e até pesquisas na internet para te ajudar, mas lembre-se: é essencial entender e refletir sobre o que está aplicando. 🚫 Evite usar o GPT sem raciocinar!
#
# ---
#
# ## **🎯 Objetivos de Aprendizado**
# - Reforçar os conceitos aprendidos ao longo do curso.
# - Manipular dados com **`pandas`** e **`numpy`**.
# - Criar visualizações com **`matplotlib`** e **`seaborn`**.
# - Desenvolver uma abordagem crítica para interpretar padrões em dados.
#
# ---
#
# ## **📝 Como entregar o Projeto Final**
#
# ### Passo a Passo:
# 1. **Prepare seu notebook**:
#    - Certifique-se de que ele está completo, organizado e com comentários explicando seu processo.
# 2. **Envie apenas esse arquivo ipynb!**:
#    - Acesse o formulário oficial: **[Link do Formulário](https://forms.gle/oDvYmwKfxscKbMaF8)**.
#    - Anexe o arquivo do seu notebook na aba "Projeto Final" e **NÃO arquive o dataset, `dados_estudantes.csv`, utilizado!**
#    - Este é o mesmo formulário utilizado para as listas de exercícios. Envie tudo junto para garantir o registro correto.
#
# ### **Prazos e Certificação**:
# - **Prazo de entrega**: Aumentamos para dia **15/12** (23h59).
# - **Certificação**: Se você completar pelo menos **70% das listas e o projeto final**, receberá um certificado oficial de conclusão. 🎓
#
# ---
#
# ## **🎁 Benefícios Extras para Alunos USP**
# Se você é aluno(a) da USP, terá a oportunidade de participar do nosso **Processo Seletivo** para integrar a equipe da FEA.dev! Após a entrega do projeto final, fique de olho no seu e-mail para mais informações.
#
# ---
#
# ## **📚 Origem dos Dados**
# Este dataset foi disponibilizado por Rabie El Kharoua no Kaggle e está licenciado sob CC BY 4.0:
#
# > El Kharoua, R. (2024). Students Performance Dataset.
# > Disponível em: [Kaggle Dataset Link](https://www.kaggle.com/datasets/rabieelkharoua/students-performance-dataset).
#
# ---
#
# ## **💡 PS: Você Chegou Até Aqui!**
#
# Estamos **muito orgulhosos** de ver o quanto você evoluiu ao longo do curso! 💪
# Este projeto é a chance perfeita de consolidar tudo o que aprendeu e mostrar do que é capaz.
#
# Lembre-se: a jornada no mundo da programação é cheia de descobertas, desafios e até frustrações (Sabemos bem como é kkk), mas cada linha de código escrita é um passo a mais rumo ao seu sucesso. Não pare por aqui! Continue explorando, aprendendo e se desafiando. O **infinito** é o seu limite.
#
# Parabéns por ter chegado até aqui! 🎉 Estamos torcendo por você e muito animados para ver o seu projeto final. Vamos juntos nessa jornada incrível! 🧑‍💻
#
# 🎯 **Agora é com você! Explore, analise e descubra os padrões escondidos nos dados. Boa sorte!** 🍀

# %% [markdown]
# ---
#
# ## **📊 Descrição das Colunas do DataFrame**
#
# ### **Identificação do Estudante**
# - **ID_Aluno**: Identificador único para cada aluno (de 1001 a 3392).
#
# ### **👥 Detalhes Demográficos**
# - **Idade**: Idade dos estudantes, variando de 15 a 18 anos.
# - **Genero**: Gênero do estudante:
#   - 0: Masculino
#   - 1: Feminino
# - **Etnia**: Etnia dos estudantes:
#   - 0: Caucasiano
#   - 1: Afrodescendente
#   - 2: Asiático
#   - 3: Outra
#
# ### **👨‍👩‍👧 Educação dos Pais**
# - **Escolaridade_Pais**: Nível de escolaridade dos pais:
#   - 0: Nenhum
#   - 1: Ensino Médio
#   - 2: Alguma Faculdade
#   - 3: Graduação
#   - 4: Pós-Graduação ou Superior
#
# ### **📚 Hábitos de Estudo**
# - **Horas_Estudo_Semanais**: Tempo de estudo semanal em horas (0 a 20).
# - **Faltas**: Número de faltas no ano letivo (0 a 30).
# - **Aulas_Particulares**: Participação em aulas particulares:
#   - 0: Não
#   - 1: Sim
#
# ### **👨‍👩‍👧 Envolvimento Parental**
# - **Apoio_Pais**: Nível de apoio dos pais:
#   - 0: Nenhum
#   - 1: Baixo
#   - 2: Moderado
#   - 3: Alto
#   - 4: Muito Alto
#
# ### **🏫 Atividades Extracurriculares**
# - **Atividades_Extracurriculares**: Participação em atividades extracurriculares:
#   - 0: Não
#   - 1: Sim
# - **Esportes**: Participação em esportes:
#   - 0: Não
#   - 1: Sim
# - **Musica**: Participação em atividades musicais:
#   - 0: Não
#   - 1: Sim
# - **Voluntariado**: Participação em atividades de voluntariado:
#   - 0: Não
#   - 1: Sim
#
# ### **📈 Desempenho Acadêmico**
# - **Media_Notas**: Média das notas (GPA), variando de 2.0 a 4.0.
# - **Classificacao_Notas**: Classificação do aluno com base na média das notas:
#   - 0: 'A' (Média >= 3.5)
#   - 1: 'B' (3.0 <= Média < 3.5)
#   - 2: 'C' (2.5 <= Média < 3.0)
#   - 3: 'D' (2.0 <= Média < 2.5)
#   - 4: 'F' (Média < 2.0)
#
# ---

# %%
# Importando as bibliotecas estudadas durante o curso
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Importando o dataset

# Verificando as primeiras linhas do dataset

# %%
traducao_colunas = {
    "StudentID": "ID_Aluno",
    "Age": "Idade",
    "Gender": "Genero",
    "Ethnicity": "Etnia",
    "ParentalEducation": "Escolaridade_Pais",
    "StudyTimeWeekly": "Horas_Estudo_Semanais",
    "Absences": "Faltas",
    "Tutoring": "Aulas_Particulares",
    "ParentalSupport": "Apoio_Pais",
    "Extracurricular": "Atividades_Extracurriculares",
    "Sports": "Esportes",
    "Music": "Musica",
    "Volunteering": "Voluntariado",
    "GPA": "Media_Notas",
    "GradeClass": "Classificacao_Notas"
}

# Renomear as colunas

# %%
# Agora está por conta própria e pronto para brilhar! 🌟

### 🔍 **Pergunta Norteadora** ###
# Quais fatores demográficos, acadêmicos e comportamentais mais influenciam a classificação e a média de notas dos estudantes?

# 🛠️ **Dicas para começar:**
# - Dê uma boa olhada no dataset.
# - Explore as relações entre a variável `Classificacao_Notas` e outros fatores, como gênero, horas de estudo, faltas, etc.
# - Use gráficos e tabelas para visualizar os padrões encontrados.
# - Escreva suas reflexões e hipóteses sobre o que você encontrou.
# - E o mais importante: divirta-se no processo de análise! 😄

# Não há limite para o número de células ou análises. O espaço é todo seu! 🚀

# **SEU CÓDIGO COMEÇA AQUI** 👇

# %%
# visao geral do dataset

dt = pd.read_csv('../data/dados_estudantes.csv', sep = ',')
dt = dt.rename(traducao_colunas, axis = 1) # traducao do nome das colunas

dt.info()
dt
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID_Aluno                      2392 non-null   int64
#  1   Idade                         2392 non-null   int64
#  2   Genero                        2392 non-null   int64
#  3   Etnia                         2392 non-null   int64
#  4   Escolaridade_Pais             2392 non-null   int64
#  5   Horas_Estudo_Semanais         2392 non-null   float64
#  6   Faltas                        2392 non-null   int64
#  7   Aulas_Particulares            2392 non-null   int64
#  8   Apoio_Pais                    2392 non-null   int64
#  9   Atividades_Extracurriculares  2392 non-null   int64
#  10  Esportes                      2392 non-null   int64
#  11  Musica                        2392 non-null   int64
#  12  Voluntariado                  2392 non-null   int64
# ...

# %%
pd.options.display.float_format = '{:.1f}'.format # definicao de visualizacao para numeros com uma casa decimal

dt.isnull().sum() # contagem de valores nulos
dt.duplicated().sum() # contagem de linhas duplicadas

# substituicao de valores das colunas
dt["Genero"] = dt.apply(
    lambda row: 'masculino' if row["Genero"] == 0
    else 'feminino',
    axis = 1
)

dt["Etnia"] = dt.apply(
    lambda row: 'caucasiano' if row["Etnia"] == 0
    else 'afrodescendente' if row["Etnia"] == 1
    else 'asiatico' if row["Etnia"] == 2 
    else 'outro',
    axis = 1
)

dt["Escolaridade_Pais"] = dt.apply(
    lambda row: 'nenhuma' if row["Escolaridade_Pais"] == 0
    else 'ensino_medio' if row["Escolaridade_Pais"] == 1
    else 'graduacao_incompleta' if row["Escolaridade_Pais"] == 2
    else 'graduacao_completa' if row["Escolaridade_Pais"] == 3
    else 'pos_graduacao',
    axis = 1
)

dt["Aulas_Particulares"] = dt.apply(
    lambda row: 'nao' if row["Aulas_Particulares"] == 0
    else 'sim',
    axis = 1
)

dt["Apoio_Pais"] = dt.apply(
    lambda row: 'nenhum' if row["Apoio_Pais"] == 0
    else 'baixo' if row["Apoio_Pais"] == 1
    else 'moderado' if row["Apoio_Pais"] == 2
    else 'alto' if row["Apoio_Pais"] == 3
    else 'muito_alto',
    axis = 1
)

dt["Atividades_Extracurriculares"] = dt.apply(
    lambda row: 'nao' if row["Atividades_Extracurriculares"] == 0
    else 'sim',
    axis = 1
)

dt["Esportes"] = dt.apply(
    lambda row: 'nao' if row["Esportes"] == 0
    else 'sim',
    axis = 1
)

dt["Musica"] = dt.apply(
    lambda row: 'nao' if row["Musica"] == 0
    else 'sim',
    axis = 1
)

dt["Voluntariado"] = dt.apply(
    lambda row: 'nao' if row["Voluntariado"] == 0
    else 'sim',
    axis = 1
)

dt["Classificacao_Notas"] = dt.apply(
    lambda row: 'A' if row["Classificacao_Notas"] == 0
    else 'B' if row["Classificacao_Notas"] == 1
    else 'C' if row["Classificacao_Notas"] == 2
    else 'D' if row["Classificacao_Notas"] == 3
    else 'F',
    axis = 1
)

dt
# Out:
#       ID_Aluno  Idade     Genero            Etnia     Escolaridade_Pais  \
# 0         1001     17   feminino       caucasiano  graduacao_incompleta
# 1         1002     18  masculino       caucasiano          ensino_medio
# 2         1003     15  masculino         asiatico    graduacao_completa
# 3         1004     17   feminino       caucasiano    graduacao_completa
# 4         1005     17   feminino       caucasiano  graduacao_incompleta
# ...        ...    ...        ...              ...                   ...
# 2387      3388     18   feminino       caucasiano    graduacao_completa
# 2388      3389     17  masculino       caucasiano          ensino_medio
# 2389      3390     16   feminino       caucasiano  graduacao_incompleta
# 2390      3391     16   feminino  afrodescendente               nenhuma
# 2391      3392     16   feminino       caucasiano  graduacao_incompleta
#
#       Horas_Estudo_Semanais  Faltas Aulas_Particulares  Apoio_Pais  \
# ...

# %%
### organizacao de colunas do dataset ###

# adicao das colunas 'esportes', 'musica' e 'voluntariado' em 'atividades extracurriculares'
dt["Atividades_Extracurriculares"] = dt.apply(
    lambda x: 'sim' if x["Atividades_Extracurriculares"] == 'sim' 
    or 'sim' in x[["Esportes", "Musica", "Voluntariado"]].values 
    else 'nao',
    axis = 1
)

# remocao das colunas 'esportes', 'musica' e 'voluntariado'
dt = dt.drop(columns=["Esportes", "Musica", "Voluntariado"])

# renomear coluna 'horas_estudo_semanais' para 'horas_estudo'
dt = dt.rename(columns={'Horas_Estudo_Semanais': 'Horas_Estudo'})

dt
# Out:
#       ID_Aluno  Idade     Genero            Etnia     Escolaridade_Pais  \
# 0         1001     17   feminino       caucasiano  graduacao_incompleta
# 1         1002     18  masculino       caucasiano          ensino_medio
# 2         1003     15  masculino         asiatico    graduacao_completa
# 3         1004     17   feminino       caucasiano    graduacao_completa
# 4         1005     17   feminino       caucasiano  graduacao_incompleta
# ...        ...    ...        ...              ...                   ...
# 2387      3388     18   feminino       caucasiano    graduacao_completa
# 2388      3389     17  masculino       caucasiano          ensino_medio
# 2389      3390     16   feminino       caucasiano  graduacao_incompleta
# 2390      3391     16   feminino  afrodescendente               nenhuma
# 2391      3392     16   feminino       caucasiano  graduacao_incompleta
#
#       Horas_Estudo  Faltas Aulas_Particulares  Apoio_Pais  \
# ...

# %% [markdown]
# ### Identificacao de Correlações Secundárias
#
# #### Dados Demograficos
# - Idade
# - Gênero
# - Etnia
# - Escolaridade dos Pais
#
# #### Dados Acadêmicos
# - Aulas Particulares
# - Atividades Extracurriculares
#
# #### Dados Comportamentais
# - Apoio dos Pais
# - horas de estudo semanal
# - Faltas

# %%
sns.set_context(font_scale = 1.2) # definicao do tamanho padrao da fonte

dt.describe()
# Out:
#        ID_Aluno  Idade  Horas_Estudo  Faltas  Media_Notas
# count    2392.0 2392.0        2392.0  2392.0       2392.0
# mean     2196.5   16.5           9.8    14.5          1.9
# std       690.7    1.1           5.7     8.5          0.9
# min      1001.0   15.0           0.0     0.0          0.0
# 25%      1598.8   15.0           5.0     7.0          1.2
# 50%      2196.5   16.0           9.7    15.0          1.9
# 75%      2794.2   17.0          14.4    22.0          2.6
# max      3392.0   18.0          20.0    29.0          4.0

# %%
## funcoes

# adicao de valores nas barras e colunas dos graficos
def valor_barras(plot, casas_decimais):
    for valor in plot.containers:
        plot.bar_label(valor, fmt=f'%.{casas_decimais}f', label_type='edge')


# geracao de graficos de colunas com uma variavel
def grafico_colunas_1(relacao, paleta):
    grafico = sns.barplot(x = relacao.index, y = relacao.values, hue = relacao.index, palette=paleta)
    return grafico

# geracao de graficos de barras com uma variavel
def grafico_barras_1(relacao, paleta):
    grafico = sns.barplot(y = relacao.index, x = relacao.values, hue = relacao.index, palette=paleta)
    return grafico


# geracao de grafico de colunas com duas variaveis
def grafico_colunas(relacao, coluna_x, tipo_relacao, paleta):
    grafico = sns.barplot(data = relacao, x = coluna_x, y = tipo_relacao, hue = coluna_x, palette=paleta)
    return grafico

# geracao de grafico de barras com duas variaveis
def grafico_barras(relacao, coluna_x, tipo_relacao, paleta):
    grafico = sns.barplot(data = relacao, y = coluna_x, x = tipo_relacao, hue = coluna_x, palette=paleta)
    return grafico


# geracao de grafico de barras agrupadas
def grafico_barras_agrupadas(relacao, coluna_x, coluna_y, tipo_relacao, paleta):
    grafico = sns.barplot(data = relacao, y = coluna_x, x = tipo_relacao, hue = coluna_y, palette=paleta)
    return grafico
    
    
# geracao de grafico de setores com uma variavel
def grafico_setores_1(relacao, paleta):
    plt.pie(relacao, labels = relacao.index, autopct="%1.1f%%", colors = sns.color_palette(paleta))

# geracao de grafico de setores com duas variaveis
def grafico_setores(coluna1_dt, coluna2_dt, valor_dt, paleta):
    dados = dt[dt[coluna1_dt] == valor_dt]
    relacao = dados[coluna2_dt].value_counts()
    grafico_setores_1(relacao, paleta)


# geracao de grafico de dispersao
def grafico_dispersao(dataframe, coluna_x, coluna_y, paleta, cor_linha_tendencia):
    sns.scatterplot(data = dataframe, x = coluna_x, y = coluna_y, color = paleta, markers='o')
    sns.regplot(data = dataframe, x = coluna_x, y = coluna_y, scatter = False, color=cor_linha_tendencia)

# %%
## secao 1

# quantidade de estudantes participantes da pesquisa por genero, idade e etnia
contagem_genero = dt['Genero'].value_counts().sort_values(ascending=False)
contagem_idade = dt['Idade'].value_counts()
contagem_etnia = dt['Etnia'].value_counts()

plt.figure(figsize=(22, 7))

# grafico 1
plt.subplot(1,3,1)
plt.title("Quantidade de Estudantes por Gênero")
grafico = grafico_barras_1(contagem_genero, 'flare_r')
valor_barras(grafico, 0)
plt.xlabel('Gênero')
plt.ylabel('Contagem')

# grafico 2
plt.subplot(1,3,2)
plt.title("Quantidade de Estudantes por Idade")
grafico = grafico_colunas_1(contagem_idade, 'flare')
valor_barras(grafico, 0)
plt.xlabel('Idade')
plt.ylabel('Contagem')

# grafico 3
plt.subplot(1,3,3)
plt.title("Quantidade de Estudantes por Etnia")
grafico_setores_1(contagem_etnia, 'magma_r')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Análise das Correlações Secundárias - Seção 1
# - Gráfico 1: A quantidade total de estudantes separada por gênero (feminino e masculino) é quase igual, sendo **a maioria estudantes do gênero feminino**.
#
# - Gráfico 2: No dataset, há estudantes de 15 a 18 anos. Os **estudantes de 15 anos são a maioria**, mas sem muitas diferenças de quantidade em relação a estudantes de outras idades.
#
# - Gráfico 3: Na separação de estudantes por etnia, há a maior discrepância: aproximadamente **metade dos estudantes do dataset são caucasianos**. A outra metade está dividida entre estudantes afrodescendentes (≈21%), asiáticos (≈20%) e outras etnias não especificadas (≈9%).
#
# **Observação:** O dataset contém informações de **2392 estudantes**. Dataset é um conjunto de dados, geralmente organizados em formato de planilha.

# %%
## secao 2

# proporcao escolaridade pais x etnia dos alunos

plt.figure(figsize=(15,15))

# estudantes caucasianos
plt.subplot(2,2,1)
plt.title("Proporção da Escolaridade dos Pais de estudantes Caucasianos")
grafico_setores('Etnia', 'Escolaridade_Pais', 'caucasiano', 'magma_r')

# estudantes afrodescendentes
plt.subplot(2,2,2)
plt.title("Proporção da Escolaridade dos Pais de estudantes Afrodescendentes")
grafico_setores('Etnia', 'Escolaridade_Pais', 'afrodescendente', 'magma_r')

# estudantes asiaticos
plt.subplot(2,2,3)
plt.title("Proporção da Escolaridade dos Pais de estudantes Asiáticos")
grafico_setores('Etnia', 'Escolaridade_Pais', 'asiatico', 'magma_r')

# estudantes outros
plt.subplot(2,2,4)
plt.title("Proporção da Escolaridade dos Pais de estudantes de Outra etnia")
grafico_setores('Etnia', 'Escolaridade_Pais', 'outro', 'magma_r')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Análise das Correlações Secundárias - Seção 2
# - A escolaridade dos pais de estudantes de todas as etnias informadas no dataset está nas **mesmas proporções**, sem grandes diferenças.
#
# - Um ponto de destaque é que a escolaridade dos pais de estudantes de **outras etnias não especificadas** apresenta uma taxa de pós-graduados (8.1%) maior do que a taxa de pais sem graduação (7.7%).

# %%
## secao 3

# genero x atividades curriculares

plt.figure(figsize=(20,6))

genero_por_atividades = dt.groupby(['Genero','Atividades_Extracurriculares']).size().reset_index(name = 'Contagem')
genero_por_atividades = genero_por_atividades.sort_values(by='Contagem', ascending=False)

plt.subplot(1,3,1)
plt.title("Relação entre Gênero e realização de Atividades Extracurriculares")
grafico = grafico_barras_agrupadas(genero_por_atividades, 'Genero', 'Atividades_Extracurriculares', 'Contagem', 'flare_r')
valor_barras(grafico, 0)
plt.xlabel("Atividades Extracurriculares")
plt.ylabel("Gênero")

# atividades extracurriculares x quantidade de faltas
atividades_por_faltas = dt.groupby('Atividades_Extracurriculares')['Faltas'].sum().reset_index(name='Total_Faltas')
atividades_por_faltas = atividades_por_faltas.sort_values(by='Total_Faltas', ascending=True)

plt.subplot(1,3,2)
plt.title("Relação entre realização de Atividades Extracurriculares e Total de Faltas de estudantes")
grafico = grafico_colunas(atividades_por_faltas, 'Atividades_Extracurriculares', 'Total_Faltas', 'flare')
valor_barras(grafico, 0)
plt.xlabel("Atividades Extracurriculares")
plt.ylabel("Quantidade de Faltas Totais")

# genero x faltas
genero_por_faltas = dt.groupby('Genero')['Faltas'].sum().reset_index(name = 'Total_Faltas')
genero_por_faltas = genero_por_faltas.sort_values(by='Total_Faltas', ascending=True)

plt.subplot(1,3,3)
plt.title("Relação entre Gênero e Total de Faltas de estudantes")
grafico = grafico_colunas(genero_por_faltas, 'Genero', 'Total_Faltas', 'flare')
valor_barras(grafico, 0)
plt.xlabel("Gênero")
plt.ylabel("Quantidade de Faltas Totais")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Análise das Correlações Secundárias - Seção 3
#
# **Observação 1:** *Atividades Extracurriculares* incluem: Música, Esportes e Voluntariado.
#
# - Gráfico 1: Estudantes do **gênero feminino realizam mais atividades extracurriculares** do que estudantes do gênero masculino. Elas também são maioria entre aqueles que não participam de atividades extracurriculares.
#
# - Gráfico 2: **Estudantes que fazem atividades extracurriculares são os que têm mais faltas**, o que pode estar relacionado ao equilíbrio entre os estudos e essas atividades.
#
# - Gráfico 3: As estudantes são as que mais participam de atividades extracurriculares. Logo, **elas também são as que apresentam maior quantidade de faltas**. É necessário ressaltar que na análise da *Seção 1* foi afirmado que estudantes do gênero masculino são minoria no dataset, o que pode influenciar essa análise.

# %%
## secao 4

# apoio dos pais x horas de estudo

plt.figure(figsize=(15,6))

apoio_por_horas_estudo = dt.groupby('Apoio_Pais')['Horas_Estudo'].mean().reset_index(name = 'Media_Horas')
apoio_por_horas_estudo = apoio_por_horas_estudo.sort_values(by='Media_Horas', ascending=False)

plt.subplot(1,2,1)
plt.title("Relação entre Apoio do Pais e média de horas de estudo semanal dos estudantes")
grafico = grafico_barras(apoio_por_horas_estudo, 'Apoio_Pais', 'Media_Horas', 'flare_r')
valor_barras(grafico, 1)
plt.xlabel("Média de Horas de Estudo Semanais")
plt.ylabel("Nível de Apoio dos Pais")

# idade x horas de estudo
idade_por_horas_estudo = dt.groupby('Idade')['Horas_Estudo'].mean().reset_index(name='Media_Horas')
idade_por_horas_estudo = idade_por_horas_estudo.sort_values(by='Media_Horas', ascending=True)

plt.subplot(1,2,2)
plt.title("Relação entre Idade e média de horas de estudo semanal dos estudantes")
grafico = grafico_colunas(idade_por_horas_estudo, 'Idade', 'Media_Horas', 'flare')
valor_barras(grafico, 1)
plt.xlabel("Idade")
plt.ylabel("Média de Horas de Estudo Semanal")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Análise das Correlações Secundárias - Seção 4
#
# - Gráfico 1: É possível verificar que os **estudantes que possuem um apoio muito alto dos pais são os que estudam, em média, mais horas semanalmente** (cerca de 10.2h por semana). Os **estudantes que recebem um apoio alto dos pais estão logo abaixo com minutos de diferença** (média aproximada de 10h por semana).
# - Também, é possível analisar que **estudantes sem apoio dos pais têm uma média semanal de estudo (9.8h), maior do que aqueles que recebem apoio moderado**. Isso sugere que esses estudantes podem ter outras motivações para estudar. **No geral, não há muitas diferenças de resultado em relação ao nível de apoio dos pais**.
#
# - Gráfico 2: Em relação à idade e média de horas semanais estudadas também **não há grandes discrepâncias**. Um adendo: como afirmado na *Seção 1*, os **estudantes de 15 anos são a maioria no dataset**, mas não tiveram nenhum destaque na análise desta seção.

# %% [markdown]
# ### Identificação das Principais Correlações
#
# **Pergunta norteadora:** Quais fatores demográficos, acadêmicos e comportamentais mais influenciam a classificação e a média de notas dos estudantes?

# %%
## dados demograficos - secao 5

plt.figure(figsize=(15,12))

# idade x media de notas
idade_por_notas = dt.groupby('Idade')['Media_Notas'].mean().reset_index(name = 'Media')
idade_por_notas = idade_por_notas.sort_values(by='Media', ascending=True)

plt.subplot(2,2,1)
plt.title("Relação entre Idade dos estudantes e Média de Notas")
grafico = grafico_colunas(idade_por_notas, 'Idade', 'Media', 'flare')
valor_barras(grafico, 2)
plt.xlabel("Idade")
plt.ylabel("Média de Notas")


# genero x media de notas
genero_por_notas = dt.groupby('Genero')['Media_Notas'].mean().reset_index(name = "Media")
genero_por_notas = genero_por_notas.sort_values(by='Media', ascending=True)

plt.subplot(2,2,2)
plt.title("Relação entre Gênero dos estudantes e Média de Notas")
grafico = grafico_colunas(genero_por_notas, 'Genero', 'Media', 'flare')
valor_barras(grafico, 2)
plt.xlabel("Gênero")
plt.ylabel("Média de Notas")

# etnia x media de notas
etnia_por_notas = dt.groupby('Etnia')['Media_Notas'].mean().reset_index(name = 'Media')
etnia_por_notas = etnia_por_notas.sort_values(by='Media', ascending=False)

plt.subplot(2,2,3)
plt.title("Relação entre Etnia dos estudantes e Média de Notas")
grafico = grafico_barras(etnia_por_notas, 'Etnia', 'Media', 'flare_r')
valor_barras(grafico, 2)
plt.xlabel("Média de Notas")
plt.ylabel("Etnia")

# escolaridade dos pais x media de notas
escolaridade_por_notas = dt.groupby('Escolaridade_Pais')['Media_Notas'].mean().reset_index(name = 'Media')
escolaridade_por_notas = escolaridade_por_notas.sort_values(by='Media', ascending=False)

plt.subplot(2,2,4)
plt.title("Relação entre Escolaridade dos Pais dos estudantes e Média de Notas")
grafico = grafico_barras(escolaridade_por_notas, 'Escolaridade_Pais', 'Media', 'flare_r')
valor_barras(grafico, 2)
plt.xlabel("Média de Notas")
plt.ylabel("Nível de Escolaridade dos Pais")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Análise das Principais Correlações - Seção 5
#
# **Observação:** As notas dos estudantes variam de 0.0 a 4.0.
#
# - Gráfico 1: Como mostrado na *Seção 4*, não há muitas diferenças entre a média de horas de estudo semanais com a idade dos estudantes. O mesmo pode-se afirmar em relação à média de nota: **todas as idades tiveram uma média de notas muito semelhante**.
#
# - Gráfico 2: **Estudantes do gênero feminino tiveram uma média de notas levemente inferior (1.89) em relação a estudantes do gênero masculino (1.92)**. Isso pode estar relacionado à maior quantidade de faltas identificada na análise da *Seção 3*.
#
# - Gráfico 3: Em relação à etnia dos estudantes e média de notas, os **estudantes da etnia afrodescendente e de outras etnias não especificadas tiveram a maior média de notas** (1.95). Vale lembrar que na *Seção 2* foi informado que a escolaridade dos pais dos estudantes de outras etnias não especificadas é a única em que a taxa de pós-graduados é maior do que a taxa de pais que não têm nenhuma graduação. **A escolaridade dos pais pode ser um dos motivos para que estudantes de outras etnias tivessem esse desempenho**. **No geral, não há muita diferença de notas entre as etnias.**
#
# - Gráfico 4: Ao mesmo tempo, é possível perceber que **estudantes cujos pais têm ensino médio como nível de escolaridade tiveram a maior média de notas (1.93)**, enquanto **estudantes cujos pais que têm pós-graduação ou graduação apresentaram as menores médias (1.82 e 1.81, respectivamente)**. Pode-se afirmar que **há uma leve inconsistência nesse quesito**.

# %%
## dados academicos - secao 6

plt.figure(figsize=(15,6))

# atividades extracurriculares x media de notas
atividades_por_notas = dt.groupby('Atividades_Extracurriculares')['Media_Notas'].mean().reset_index(name = "Media")
atividades_por_notas = atividades_por_notas.sort_values(by='Media', ascending=True)

plt.subplot(1,2,1)
plt.title("Relação entre realização de Atividades Extracurriculares e Média de Notas")
grafico = grafico_colunas(atividades_por_notas, 'Atividades_Extracurriculares', 'Media', 'flare')
valor_barras(grafico, 2)
plt.xlabel("Realização de Atividades Extracurriculares")
plt.ylabel("Média de Notas")


# aulas particulares x media de notas
aulas_part_por_notas = dt.groupby('Aulas_Particulares')['Media_Notas'].mean().reset_index(name = "Media")
aulas_part_por_notas = aulas_part_por_notas.sort_values(by='Media', ascending=True)

plt.subplot(1,2,2)
plt.title("Relação entre participação de Aulas Particulares e Média de Notas")
grafico = grafico_colunas(aulas_part_por_notas, 'Aulas_Particulares', 'Media', 'flare')
valor_barras(grafico, 2)
plt.xlabel("Participação de Aulas Particulares")
plt.ylabel("Média de Notas")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Análise das Principais Correlações - Seção 6
#
# Gráfico 1: Em relação à atividades extracurriculares e a média de notas há uma diferença maior: é possível afirmar que **estudantes que fazem atividades extracurriculares tiveram uma nota maior (1.97) do que os estudantes que não fazem (1.75)**. Vale ressaltar que nas *Seções 3 e 5* foi possível analisar que estudantes do gênero feminino tiveram uma menor média de notas em relação aos estudantes do gênero masculino (sendo a quantidade de faltas, um dos motivos), mesmo realizando mais atividades extracurriculares. **É possível que haja uma pequena inconsistência nessas relações**.
#
# Gráfico 2: Mesmo não sendo citado ao longo da análise, o dataset possui informações sobre participação de estudantes em aulas particulares. O resultado também teve uma grande diferença: **estudantes que têm aulas particulares possuem uma média de nota maior (2.11) do que os que não têm (1.82)**. Isso pode ser um indicativo de grande influência na nota de um estudante.

# %%
## dados comportamentais - secao 7

plt.figure(figsize=(20,6))

# horas de estudo x media de notas
plt.subplot(1,3,1)
plt.title("Relação entre horas de estudo semanal e Média de Notas")
grafico_dispersao(dt, 'Horas_Estudo', 'Media_Notas', '#d27979', '#872c2c')
plt.xlabel("Quantidade de Horas de Estudo Semanais")
plt.ylabel("Média de Notas")


# quantidade de faltas x media de notas
plt.subplot(1,3,2)
plt.title("Relação entre Quantidade de Faltas e Média de Notas")
grafico_dispersao(dt, 'Faltas', 'Media_Notas', '#d27979', '#872c2c')
plt.xlabel("Quantidade de Faltas")
plt.ylabel("Média de Notas")


# apoio dos pais x media de notas
apoio_por_notas = dt.groupby('Apoio_Pais')['Media_Notas'].mean().reset_index(name = 'Media')
apoio_por_notas = apoio_por_notas.sort_values(by='Media', ascending=False)

plt.subplot(1,3,3)
plt.title("Relação entre o Apoio dos Pais e a Média de Notas")
grafico = grafico_barras(apoio_por_notas, 'Apoio_Pais', 'Media', 'flare_r')
valor_barras(grafico, 2)
plt.xlabel("Média de Notas")
plt.ylabel("Nível de Apoio dos Pais")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Análise das Principais Correlações - Seção 7
#
# Gráfico 1: Em relação às horas de estudo semanais e a média de nota, é possível notar a maior inconsistência da análise, tornando essa relação pouco confiável. Mesmo que a linha de tendência do gráfico indique que *mais horas de estudo semanal levam a uma maior média de notas*, é possível verificar que **há centenas de exceções a essa afirmação**. Analisando por esse dataset, **não é possível afirmar que as horas de estudo semanal de um estudante afetem diretamente a sua nota**.
#
# Gráfico 2: Em relação à quantidade de faltas e a média de nota, não há tantas inconsistências e é possível verificar um padrão: **quanto mais faltas, menor a média de notas**. Essa variável é mais precisa, sem muitas exceções, em relação à definição da nota de um estudante.
#
# Gráfico 3: É possível verificar uma grande discrepância: **estudantes que recebem um apoio muito alto dos pais tem a média de nota significativamente maior (2.19) do que aqueles que têm um apoio baixo ou nenhum dos pais (1.76 e 1.54, respectivamente)**. É importante lembrar que na *Seção 4*, o apoio dos pais não fez muita diferença em relação a quantidade de horas semanais estudadas.

# %%
## secao 8

# classificacao x quantidade de notas

plt.figure(figsize=(8,8))

contagem_notas = dt['Classificacao_Notas'].value_counts()

plt.title("Proporção da Classificação das Notas e Quantidade de Notas")
grafico_setores_1(contagem_notas, 'magma_r')

plt.tight_layout
plt.show()

# %% [markdown]
# ### Análise das Principais Correlações - Seção 8
#
# Pelo gráfico de setores, é possível notar que há uma grande discrepância de classificação de notas: **aproximadamente metade dos estudantes do dataset receberam uma classificação de nota 'F'**, ou seja, obtiveram uma média de nota menor que 2.0. A outra metade está dividida entre as notas 'D', 'C', 'B', 'A'. **Apenas 4.5% dos estudantes do dataset reberam uma classificação de nota 'A'**, ou seja, tiveram uma média maior que 3.5.

# %% [markdown]
# ## **Conclusão da Análise**
#
# #### Principais fatores que afetam a média de notas dos estudantes:
# - Participação em aulas particulares;
# - Apoio dos pais;
# - Frequência escolar.
#
# Ter um apoio externo, como aulas particulares, tem um impacto forte em relação ao aprendizado. Além disso, ter um bom suporte dos pais e evitar faltas escolares também possuem um papel importante para o sucesso acadêmico dos estudantes.
#
# #### Fatores que menos afetam a média de notas:
# - Idade dos estudantes;
# - Escolaridade dos pais;
# - Quantidade de horas semanais estudadas.
#
# As análises realizadas indicam que esses fatores não possuem tanto impacto direto sobre as notas dos estudantes e não foram tão determinantes no desempenho escolar.
#
# #### Possíveis Melhorias no Sistema Educacional
#
# 1. **Promoção de aulas particulares acessíveis**: Investir em programas de reforço escolar, principalmente para estudantes em situação de vulnerabilidade, pode ser uma boa forma de melhorar o desempenho acadêmico.
#
# 2. **Apoio emocional dos pais/responsáveis**: Incentivar a participação ativa dos pais/responsáveis no processo educacional dos filhos pode ter um grande impacto. Isso pode ser feito por meio reuniões escolares sobre a importância do envolvimento parental na vida escolar de um estudante.
#
# 3. **Incentivo às atividades extracurriculares balanceadas**: Atividades extracurriculares são importantes para o desenvolvimento geral dos estudantes, mas é necessário que sejam feitas de modo que não prejudiquem a frequência escolar. É importante promover o equilíbrio entre lazer e estudos.
#
# 4. **Redução de faltas escolares**: Faltas excessivas podem comprometer o desempenho dos alunos. Para diminuir esse problema, é necessário tomar medidas para identificar as causas das ausências e oferecer soluções, como transporte escolar e suporte psicológico.
#
#
# ### **Encerramento**
# É importante não generalizar as conclusões baseadas em um único conjunto de dados. Para ter resultados mais precisos e completos da área educacional, é necessário realizar as análises com populações maiores e mais diversificadas.
